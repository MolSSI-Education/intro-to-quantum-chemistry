# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !mamba install -c conda-forge psi4 -y
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...
#
# Looking for: ['psi4']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   9%
# conda-forge/noarch    15%[+] 0.3s
# conda-forge/linux-64  17%
# conda-forge/noarch    33%[+] 0.4s
# conda-forge/linux-64  25%
# conda-forge/noarch    44%[+] 0.5s
# conda-forge/linux-64  28%
# conda-forge/noarch    56%[+] 0.6s
# conda-forge/linux-64  32%
# conda-forge/noarch    66%[+] 0.7s
# conda-forge/linux-64  37%
# conda-forge/noarch    78%[+] 0.8s
# conda-forge/linux-64  43%
# conda-forge/noarch    91%conda-forge/noarch
# [+] 0.9s
# conda-forge/linux-64  49%[+] 1.0s
# conda-forge/linux-64  59%[+] 1.1s
# conda-forge/linux-64  70%[+] 1.2s
# conda-forge/linux-64  79%[+] 1.3s
# conda-forge/linux-64  91%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - psi4
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                 Version  Build                  Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────
#
#   + msgpack-python          1.1.0  py311hd18a35c_0        conda-forge      105kB
#   + gau2grid                2.0.7  h4bc722e_4             conda-forge      387kB
#   + pugixml                  1.14  h59595ed_0             conda-forge      115kB
#   + libint                  2.9.0  h23769fb_2             conda-forge       76MB
#   + libxc-c                 7.0.0  cpu_h20a523f_2         conda-forge       59MB
#   + llvm-openmp            19.1.7  h024ca30_0             conda-forge        3MB
#   + libgfortran5           14.2.0  hd5240d6_1             conda-forge        1MB
#   + psutil                  6.1.1  py311h9ecbd09_0        conda-forge      505kB
#   + libhwloc               2.11.2  default_h0d58e46_1001  conda-forge        2MB
#   + yaml                    0.2.5  h7f98852_2             conda-forge       89kB
#   + libecpint               1.0.7  h5c03a75_11            conda-forge      341kB
#   + libgfortran            14.2.0  h69a702a_1             conda-forge       54kB
#   + tbb                 2021.13.0  hceb3a55_1             conda-forge      176kB
#   + pyyaml                  6.0.2  py311h2dc5d0c_2        conda-forge      213kB
#   + libpcm                  1.2.3  hdca9e5a_14            conda-forge      570kB
#   + mkl                  2023.2.0  h84fe81f_50496         conda-forge      164MB
#   + libblas                 3.9.0  20_linux64_mkl         conda-forge       15kB
#   + dkh                       1.2  h168aa07_2             conda-forge       64kB
#   + libcblas                3.9.0  20_linux64_mkl         conda-forge       14kB
#   + liblapack               3.9.0  20_linux64_mkl         conda-forge       14kB
#   + numpy                   2.2.2  py311h5d046bc_0        conda-forge        9MB
#   + scipy                  1.15.1  py311hc1ac118_0        conda-forge       19MB
#   + networkx                3.4.2  pyh267e887_2           conda-forge        1MB
#   + py-cpuinfo              9.0.0  pyhd8ed1ab_1           conda-forge       26kB
#   + typing_extensions      4.12.2  pyha770c72_1           conda-forge       40kB
#   + pcmsolver               1.2.3  py_14                  conda-forge       98kB
#   + typing-extensions      4.12.2  hd8ed1ab_1             conda-forge       10kB
#   + flexparser                0.4  pyhd8ed1ab_1           conda-forge       29kB
#   + flexcache                 0.3  pyhd8ed1ab_1           conda-forge       17kB
#   + annotated-types         0.7.0  pyhd8ed1ab_1           conda-forge       18kB
#   + pint                   0.24.4  pyhd8ed1ab_1           conda-forge      230kB
#   + pydantic-core          2.27.2  py311h9e33e62_0        conda-forge        2MB
#   + pydantic               2.10.6  pyh3cfb1c2_0           conda-forge      297kB
#   + qcelemental            0.29.0  pyhd8ed1ab_0           conda-forge      256kB
#   + qcengine               0.31.0  pyhd8ed1ab_0           conda-forge      243kB
#   + optking                 0.3.0  pyhd8ed1ab_0           conda-forge      143kB
#   + psi4                    1.9.1  py311h2ae924c_8        conda-forge       29MB
#
#   Change:
# ──────────────────────────────────────────────────────────────────────────────────
#
#   - _openmp_mutex             4.5  2_gnu                  conda-forge     Cached
#   + _openmp_mutex             4.5  2_kmp_llvm             conda-forge        6kB
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates    2024.12.14  hbcca054_0             conda-forge     Cached
#   + ca-certificates     2025.1.31  hbcca054_0             conda-forge      158kB
#
#   Summary:
#
#   Install: 37 packages
#   Change: 1 packages
#   Upgrade: 1 packages
#
#   Total download: 372MB
#
# ──────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   1%
# Extracting         0%msgpack-python                                     104.8kB @   1.0MB/s  0.1s
# pugixml                                            114.9kB @ 858.5kB/s  0.1s
# gau2grid                                           386.7kB @   2.3MB/s  0.2s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (2)  ⣾  ca-certificates                                    158.1kB @ 749.7kB/s  0.2s
# psutil                                             505.0kB @   2.3MB/s  0.1s
# libecpint                                          341.1kB @   1.4MB/s  0.1s
# tbb                                                176.0kB @ 655.1kB/s  0.1s
# libcblas                                            14.4kB @  49.6kB/s  0.0s
# [+] 0.3s
# Downloading  (5)   3%
# Extracting   (5)  ⣾  typing_extensions                                   39.6kB @ 118.2kB/s  0.0s
# [+] 0.4s
# Downloading  (5)   7%
# Extracting   (7)  ⣾  flexparser                                          28.7kB @  71.0kB/s  0.1s
# pint                                               230.2kB @ 464.0kB/s  0.1s
# [+] 0.5s
# Downloading  (4)   8%
# Extracting   (6)  ⣾  qcelemental                                        255.9kB @ 453.7kB/s  0.1s
# [+] 0.6s
# Downloading  (5)  10%
# Extracting   (8)  ⣾  [+] 0.7s
# Downloading  (5)  12%
# Extracting   (7)  ⣾  [+] 0.8s
# Downloading  (5)  15%
# Extracting   (5)  ⣾  [+] 0.9s
# Downloading  (5)  17%
# Extracting   (4)  ⣾  [+] 1.0s
# Downloading  (5)  19%
# Extracting   (2)  ⣾  [+] 1.1s
# Downloading  (5)  22%
# Extracting   (2)  ⣾  [+] 1.2s
# Downloading  (5)  25%
# Extracting        31%scipy                                               19.2MB @  15.1MB/s  1.0s
# [+] 1.3s
# Downloading  (5)  30%
# Extracting   (1)  ⣾  [+] 1.4s
# Downloading  (5)  35%
# Extracting   (1)  ⣾  libhwloc                                             2.4MB @   1.7MB/s  0.1s
# libgfortran                                         54.0kB @  36.2kB/s  0.1s
# [+] 1.5s
# Downloading  (5)  38%
# Extracting   (2)  ⣾  libblas                                             14.9kB @   9.6kB/s  0.1s
# [+] 1.6s
# Downloading  (5)  39%
# Extracting   (4)  ⣾  [+] 1.7s
# Downloading  (5)  43%
# Extracting   (3)  ⣾  [+] 1.8s
# Downloading  (5)  47%
# Extracting   (3)  ⣾  [+] 1.9s
# Downloading  (5)  49%
# Extracting   (2)  ⣾  [+] 2.0s
# Downloading  (5)  51%
# Extracting   (1)  ⣾  numpy                                                9.1MB @   4.5MB/s  0.5s
# [+] 2.1s
# Downloading  (5)  55%
# Extracting   (2)  ⣾  psi4                                                29.4MB @  14.0MB/s  1.5s
# pcmsolver                                           97.8kB @  46.4kB/s  0.1s
# annotated-types                                     18.1kB @   8.3kB/s  0.1s
# [+] 2.2s
# Downloading  (5)  57%
# Extracting   (5)  ⣾  pydantic-core                                        1.6MB @ 735.0kB/s  0.1s
# pyyaml                                             213.1kB @  93.2kB/s  0.1s
# [+] 2.3s
# Downloading  (5)  60%
# Extracting   (7)  ⣾  liblapack                                           14.4kB @   6.2kB/s  0.0s
# libgfortran5                                         1.5MB @ 618.5kB/s  0.2s
# [+] 2.4s
# Downloading  (5)  61%
# Extracting   (8)  ⣾  typing-extensions                                   10.1kB @   4.1kB/s  0.1s
# qcengine                                           242.7kB @  99.4kB/s  0.1s
# [+] 2.5s
# Downloading  (5)  62%
# Extracting  (10)  ⣾  yaml                                                89.1kB @  35.5kB/s  0.1s
# _openmp_mutex                                        5.7kB @   2.3kB/s  0.1s
# flexcache                                           16.7kB @   6.5kB/s  0.1s
# pydantic                                           296.8kB @ 115.5kB/s  0.1s
# [+] 2.6s
# Downloading  (5)  63%
# Extracting  (14)  ⣾  py-cpuinfo                                          25.8kB @   9.7kB/s  0.1s
# optking                                            142.9kB @  53.1kB/s  0.0s
# [+] 2.7s
# Downloading  (4)  64%
# Extracting  (15)  ⣾  networkx                                             1.3MB @ 468.6kB/s  0.1s
# dkh                                                 63.9kB @  23.0kB/s  0.1s
# [+] 2.8s
# Downloading  (5)  66%
# Extracting  (16)  ⣾  llvm-openmp                                          3.2MB @   1.1MB/s  0.2s
# libpcm                                             570.3kB @ 199.9kB/s  0.1s
# libxc-c                                             59.4MB @  20.8MB/s  2.8s
# [+] 2.9s
# Downloading  (2)  69%
# Extracting  (20)  ⣾  [+] 3.0s
# Downloading  (2)  71%
# Extracting  (20)  ⣾  [+] 3.1s
# Downloading  (2)  74%
# Extracting  (20)  ⣾  libint                                              76.2MB @  24.4MB/s  3.1s
# [+] 3.2s
# Downloading  (1)  76%
# Extracting  (21)  ⣾  [+] 3.3s
# Downloading  (1)  78%
# Extracting  (21)  ⣾  [+] 3.4s
# Downloading  (1)  80%
# Extracting  (21)  ⣾  [+] 3.5s
# Downloading  (1)  80%
# Extracting  (21)  ⣾  [+] 3.6s
# Downloading  (1)  82%
# Extracting  (21)  ⣾  [+] 3.7s
# Downloading  (1)  83%
# Extracting  (21)  ⣾  [+] 3.8s
# Downloading  (1)  84%
# Extracting  (20)  ⣾  [+] 3.9s
# Downloading  (1)  85%
# Extracting  (20)  ⣾  [+] 4.0s
# Downloading  (1)  86%
# Extracting  (19)  ⣾  [+] 4.1s
# Downloading  (1)  88%
# Extracting  (18)  ⣾  [+] 4.2s
# Downloading  (1)  91%
# Extracting  (17)  ⣾  [+] 4.3s
# Downloading  (1)  94%
# Extracting  (14)  ⣾  [+] 4.4s
# Downloading  (1)  96%
# Extracting  (14)  ⣾  [+] 4.5s
# Downloading  (1)  98%
# Extracting  (14)  ⣾  [+] 4.6s
# Downloading  (1) 100%
# Extracting  (14)  ⣾  mkl                                                164.4MB @  35.7MB/s  4.4s
# [+] 4.7s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
import psi4

# Set up the molecule
mol = psi4.geometry("""
0 1
H
H 1 0.74
symmetry c1
""")

# Set computation options
psi4.set_options({'reference': 'rhf'})

# Run HF/aug-cc-pVDZ geometry optimization
psi4.optimize('hf/aug-cc-pVDZ')
# Out:
# Optimizer: Optimization complete!
# -1.1288264866181772
